# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
files = ["events_PureSM.csv","events_PureAQGC_1em12.csv","events_PureAQGC_1em11.csv", "events_Int_1em12.csv","events_Int_1em11.csv"]

# %%
col = 'l1Eta'

# %%
info = pd.read_csv(files[0], delimiter=" ")

# %%
info_col = info[col]

# %%
plt.xlabel(col)
plt.ylabel("occurence")
plt.title("histogram for " + col)
plt.hist(info_col, bins = 100)
# Out:
# (array([ 8., 19.,  3.,  9., 17., 13., 12., 23., 15., 19., 16., 16., 19.,
#         14., 14., 20., 18., 26., 27., 28., 21., 21., 22., 27., 23., 24.,
#         30., 30., 19., 31., 40., 32., 29., 30., 23., 39., 35., 35., 25.,
#         31., 37., 27., 43., 30., 31., 45., 39., 27., 30., 42., 33., 22.,
#         27., 38., 37., 34., 33., 32., 31., 41., 39., 37., 28., 32., 39.,
#         35., 36., 29., 29., 43., 27., 26., 36., 24., 26., 34., 25., 29.,
#         23., 21., 29., 23., 22., 17., 23., 21., 17., 14., 11., 16., 11.,
#         15., 15.,  7., 11., 12., 14.,  8., 10.,  6.]),
#  array([-2.4807  , -2.430894, -2.381088, -2.331282, -2.281476, -2.23167 ,
#         -2.181864, -2.132058, -2.082252, -2.032446, -1.98264 , -1.932834,
#         -1.883028, -1.833222, -1.783416, -1.73361 , -1.683804, -1.633998,
#         -1.584192, -1.534386, -1.48458 , -1.434774, -1.384968, -1.335162,
#         -1.285356, -1.23555 , -1.185744, -1.135938, -1.086132, -1.036326,
# ...
